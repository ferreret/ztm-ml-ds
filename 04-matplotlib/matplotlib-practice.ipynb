# %% [markdown]
# # Matplotlib Exercises

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot();

# %%
x = [1, 2, 3, 4, 5]
plt.plot(x);

# %%
X = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
plt.plot(X, y);

# %%
fig, ax = plt.subplots()
ax.plot(X, y);
ax.set(xlabel='X label', ylabel='Y label', title='Title');

# %%
import numpy as np

X = np.linspace(0, 100, 100)
X
# Out:
# array([  0.        ,   1.01010101,   2.02020202,   3.03030303,
#          4.04040404,   5.05050505,   6.06060606,   7.07070707,
#          8.08080808,   9.09090909,  10.1010101 ,  11.11111111,
#         12.12121212,  13.13131313,  14.14141414,  15.15151515,
#         16.16161616,  17.17171717,  18.18181818,  19.19191919,
#         20.2020202 ,  21.21212121,  22.22222222,  23.23232323,
#         24.24242424,  25.25252525,  26.26262626,  27.27272727,
#         28.28282828,  29.29292929,  30.3030303 ,  31.31313131,
#         32.32323232,  33.33333333,  34.34343434,  35.35353535,
#         36.36363636,  37.37373737,  38.38383838,  39.39393939,
#         40.4040404 ,  41.41414141,  42.42424242,  43.43434343,
#         44.44444444,  45.45454545,  46.46464646,  47.47474747,
#         48.48484848,  49.49494949,  50.50505051,  51.51515152,
#         52.52525253,  53.53535354,  54.54545455,  55.55555556,
#         56.56565657,  57.57575758,  58.58585859,  59.5959596 ,
# ...

# %%
fig, ax = plt.subplots()
ax.plot(X, np.square(X));

# %%
fig, ax = plt.subplots()
ax.scatter(X, np.exp(X));

# %%
fig, ax = plt.subplots()
ax.plot(X, np.sin(X));

# %%
foods = {
    "Sushi": 123,
    "Pizza": 456,
    "Ice Cream": 789,
}

fig, ax = plt.subplots()
ax.set(title="My favorite foods", xlabel="Food", ylabel="Price");
ax.bar(foods.keys(), foods.values());

# %%
fig, ax = plt.subplots()
ax.set(title="My favorite foods", xlabel="Food", ylabel="Price");
ax.barh(list(foods.keys()), foods.values());

# %%
X = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(X);

# %%
X = np.random.random(1000)
fig, ax = plt.subplots()
ax.hist(X);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(10, 5))
ax1.plot(X, np.divide(X,2));
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(foods.keys(), foods.values());
ax4.hist(np.random.randn(1000));

# %%
import pandas as pd

car_sales = pd.read_csv("car-sales.csv")

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[$\.\, ]", "")
# Out:
# /tmp/ipykernel_58945/3799235083.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[$\.\, ]", "")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]

# %%
car_sales["Price"] = car_sales["Price"].astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales
# 0  Toyota  White         150043      4   4000.0       4000.0
# 1   Honda    Red          87899      4   5000.0       9000.0
# 2  Toyota   Blue          32549      3   7000.0      16000.0
# 3     BMW  Black          11179      5  22000.0      38000.0
# 4  Nissan  White         213095      4   3500.0      41500.0
# 5  Toyota  Green          99213      4   4500.0      46000.0
# 6   Honda   Blue          45698      4   7500.0      53500.0
# 7   Honda   Blue          54738      4   7000.0      60500.0
# 8  Toyota  White          60000      4   6250.0      66750.0
# 9  Nissan  White          31600      4   9700.0      76450.0

# %%
car_sales["Sale Date"] = pd.date_range(pd.datetime.today(), periods=len(car_sales))
# Out:
# /tmp/ipykernel_58945/1905682564.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   car_sales["Sale Date"] = pd.date_range(pd.datetime.today(), periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Total Sales  \
# 0  Toyota  White         150043      4   4000.0       4000.0
# 1   Honda    Red          87899      4   5000.0       9000.0
# 2  Toyota   Blue          32549      3   7000.0      16000.0
# 3     BMW  Black          11179      5  22000.0      38000.0
# 4  Nissan  White         213095      4   3500.0      41500.0
# 5  Toyota  Green          99213      4   4500.0      46000.0
# 6   Honda   Blue          45698      4   7500.0      53500.0
# 7   Honda   Blue          54738      4   7000.0      60500.0
# 8  Toyota  White          60000      4   6250.0      66750.0
# 9  Nissan  White          31600      4   9700.0      76450.0
#
#                    Sale Date
# 0 2022-05-04 13:29:16.919360
# 1 2022-05-05 13:29:16.919360
# 2 2022-05-06 13:29:16.919360
# 3 2022-05-07 13:29:16.919360
# 4 2022-05-08 13:29:16.919360
# 5 2022-05-09 13:29:16.919360
# 6 2022-05-10 13:29:16.919360
# 7 2022-05-11 13:29:16.919360
# ...

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  \
# 0  Toyota  White         150043      4   4000       4000.0
# 1   Honda    Red          87899      4   5000       9000.0
# 2  Toyota   Blue          32549      3   7000      16000.0
# 3     BMW  Black          11179      5  22000      38000.0
# 4  Nissan  White         213095      4   3500      41500.0
# 5  Toyota  Green          99213      4   4500      46000.0
# 6   Honda   Blue          45698      4   7500      53500.0
# 7   Honda   Blue          54738      4   7000      60500.0
# 8  Toyota  White          60000      4   6250      66750.0
# 9  Nissan  White          31600      4   9700      76450.0
#
#                    Sale Date
# 0 2022-05-04 13:48:32.119807
# 1 2022-05-05 13:48:32.119807
# 2 2022-05-06 13:48:32.119807
# 3 2022-05-07 13:48:32.119807
# 4 2022-05-08 13:48:32.119807
# 5 2022-05-09 13:48:32.119807
# 6 2022-05-10 13:48:32.119807
# 7 2022-05-11 13:48:32.119807
# 8 2022-05-12 13:48:32.119807
# ...

# %%
car_sales["Odometer (KM)"].dtype
# Out:
# dtype('int64')

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
X = np.random.random(size=(10,4))
X
# Out:
# array([[0.55934006, 0.76847676, 0.0399081 , 0.31620278],
#        [0.74618744, 0.61359835, 0.69952892, 0.9023951 ],
#        [0.60075769, 0.44485183, 0.13344045, 0.53994799],
#        [0.80428742, 0.21323882, 0.26818648, 0.94348267],
#        [0.09419427, 0.15857717, 0.10997596, 0.09936717],
#        [0.56242578, 0.48496905, 0.48983541, 0.71014297],
#        [0.86535145, 0.90961712, 0.85527913, 0.22326023],
#        [0.69113778, 0.02937473, 0.31297654, 0.75405279],
#        [0.75357111, 0.81488169, 0.82223696, 0.70706859],
#        [0.28502088, 0.6667429 , 0.61656717, 0.63081472]])

# %%
df_X = pd.DataFrame(X, columns=["a", "b", "c", "d"])

# %%
df_X
# Out:
#           a         b         c         d
# 0  0.559340  0.768477  0.039908  0.316203
# 1  0.746187  0.613598  0.699529  0.902395
# 2  0.600758  0.444852  0.133440  0.539948
# 3  0.804287  0.213239  0.268186  0.943483
# 4  0.094194  0.158577  0.109976  0.099367
# 5  0.562426  0.484969  0.489835  0.710143
# 6  0.865351  0.909617  0.855279  0.223260
# 7  0.691138  0.029375  0.312977  0.754053
# 8  0.753571  0.814882  0.822237  0.707069
# 9  0.285021  0.666743  0.616567  0.630815

# %%
df_X.plot.bar()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot.bar(x="Make", y="Odometer (KM)");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Price"].plot.hist(bins=20);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(bins=50, subplots=True, figsize=(10,30));
